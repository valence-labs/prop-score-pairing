# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data_dir = "/mnt/ps/home/CORP/johnny.xi/sandbox/matching/data/datasets/noisyballs_scm_non_linear/intervention/"
balls1 = np.load(data_dir +  'train_' + 'x1' + '.npy')
balls2 = np.load(data_dir +  'train_' + 'x2' + '.npy')

# %%
np.divide(balls1, 255).transpose((3,0,1,2)).reshape((3, -1)).mean(axis = 1)
# Out:
# array([0.50454001, 0.75075871, 0.40544085])

# %%
np.divide(balls1, 255).transpose((3, 0,1,2)).reshape((3, -1)).std(axis = 1)
# Out:
# array([0.29195627, 0.14611416, 0.05556526])

# %%
np.divide(balls2, 255).transpose((3,0,1,2)).reshape((3, -1)).mean(axis = 1)
# Out:
# array([0.98185011, 0.75588502, 0.09406329])

# %%
np.divide(balls2, 255).transpose((3,0,1,2)).reshape((3, -1)).std(axis = 1)
# Out:
# array([0.05103349, 0.15451756, 0.15762656])

# %%
plt.imshow(balls1[0])

# %%
plt.imshow(balls2[0])
